# %% [markdown]
# # NHANES Data Exploration
#
# CC-1089
#
# Using data from the CDC/NHANES 2017-March 2020 Examination data:
# https://wwwn.cdc.gov/nchs/nhanes/search/datapage.aspx?Component=Examination&Cycle=2017-2020
#
# Attempts at visualizing health data from NHANES.
#
# The first data being looked at is anthropometric, or body measurements. These are physical measurements of lengths, circumferences, other anatomical aspects of the human body.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Body Measure Data

# %%
bmdata = pd.read_sas('data/P_BMX.XPT')
bmnames = {
    'SEQN' : 'Respondent sequence number',
    'BMDSTATS' : 'Body Measures Component Status Code',
    'BMXWT' : 'Weight (kg)',
    'BMIWT' : 'Weight Comment',
    'BMXRECUM' : 'Recumbent Length (cm)',
    'BMIRECUM' : 'Recumbent Length Comment',
    'BMXHEAD' : 'Head Circumference (cm)',
    'BMIHEAD' : 'Head Circumference Comment',
    'BMXHT' : 'Standing Height (cm)',
    'BMIHT' : 'Standing Height Comment',
    'BMXBMI' : r'Body Mass Index ($kg/m^2$)',
    'BMDBMIC' : 'BMI Category - Children/Youth',
    'BMXLEG' : 'Upper Leg Length (cm)',
    'BMILEG' : 'Upper Leg Length Comment',
    'BMXARML' : 'Upper Arm Length (cm)',
    'BMIARML' : 'Upper Arm Length Comment',
    'BMXARMC' : 'Arm Circumference (cm)',
    'BMIARMC' : 'Arm Circumference Comment',
    'BMXWAIST' : 'Waist Circumference (cm)',
    'BMIWAIST' : 'Waist Circumference Comment',
    'BMXHIP' : 'Hip Circumference (cm)',
    'BMIHIP' : 'Hip Circumference Comment'}
bmdata.rename(columns=bmnames, inplace=True)
bmdata
# Out:
#        Respondent sequence number  Body Measures Component Status Code  \
# 0                        109263.0                                  4.0
# 1                        109264.0                                  1.0
# 2                        109265.0                                  1.0
# 3                        109266.0                                  1.0
# 4                        109269.0                                  3.0
# ...                           ...                                  ...
# 14295                    124818.0                                  1.0
# 14296                    124819.0                                  1.0
# 14297                    124820.0                                  1.0
# 14298                    124821.0                                  1.0
# 14299                    124822.0                                  1.0
#
#        Weight (kg)  Weight Comment  Recumbent Length (cm)  \
# 0              NaN             NaN                    NaN
# 1             42.2             NaN                    NaN
# 2             12.0             NaN                   91.6
# 3             97.1             NaN                    NaN
# 4             13.6             NaN                   90.9
# ...            ...             ...                    ...
# 14295        108.8             NaN                    NaN
# 14296         15.4             NaN                   94.9
# 14297         22.9             NaN                    NaN
# 14298         79.5             NaN                    NaN
# 14299         59.7             NaN                    NaN
#
#        Recumbent Length Comment  Head Circumference (cm)  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# ...                         ...                      ...
# 14295                       NaN                      NaN
# 14296                       NaN                      NaN
# 14297                       NaN                      NaN
# 14298                       NaN                      NaN
# 14299                       NaN                      NaN
#
#        Head Circumference Comment  Standing Height (cm)  \
# 0                             NaN                   NaN
# 1                             NaN                 154.7
# 2                             NaN                  89.3
# 3                             NaN                 160.2
# 4                             NaN                   NaN
# ...                           ...                   ...
# 14295                         NaN                 168.7
# 14296                         NaN                  93.7
# 14297                         NaN                 123.3
# 14298                         NaN                 176.4
# 14299                         NaN                 167.5
#
#        Standing Height Comment  ...  Upper Leg Length (cm)  \
# 0                          NaN  ...                    NaN
# 1                          NaN  ...                   36.3
# 2                          NaN  ...                    NaN
# 3                          NaN  ...                   40.8
# 4                          1.0  ...                    NaN
# ...                        ...  ...                    ...
# 14295                      3.0  ...                   45.6
# 14296                      NaN  ...                    NaN
# 14297                      NaN  ...                    NaN
# 14298                      NaN  ...                   42.0
# 14299                      NaN  ...                   41.1
#
#        Upper Leg Length Comment  Upper Arm Length (cm)  \
# 0                           NaN                    NaN
# 1                           NaN                   33.8
# 2                           NaN                   18.6
# 3                           NaN                   34.7
# 4                           NaN                    NaN
# ...                         ...                    ...
# 14295                       NaN                   38.6
# 14296                       NaN                   17.5
# 14297                       NaN                   24.3
# 14298                       NaN                   39.5
# 14299                       NaN                   40.3
#
#        Upper Arm Length Comment  Arm Circumference (cm)  \
# 0                           NaN                     NaN
# 1                           NaN                    22.7
# 2                           NaN                    14.8
# 3                           NaN                    35.8
# 4                           1.0                     NaN
# ...                         ...                     ...
# 14295                       NaN                    33.6
# 14296                       NaN                    15.8
# 14297                       NaN                    18.5
# 14298                       NaN                    31.4
# 14299                       NaN                    29.2
#
#        Arm Circumference Comment  Waist Circumference (cm)  \
# 0                            NaN                       NaN
# 1                            NaN                      63.8
# 2                            NaN                      41.2
# 3                            NaN                     117.9
# 4                            1.0                       NaN
# ...                          ...                       ...
# 14295                        NaN                     114.7
# 14296                        NaN                      48.4
# 14297                        NaN                      57.5
# 14298                        NaN                      97.1
# 14299                        NaN                      86.9
#
#        Waist Circumference Comment  Hip Circumference (cm)  \
# 0                              NaN                     NaN
# 1                              NaN                    85.0
# 2                              NaN                     NaN
# 3                              NaN                   126.1
# 4                              1.0                     NaN
# ...                            ...                     ...
# 14295                          NaN                   118.0
# 14296                          NaN                     NaN
# 14297                          NaN                     NaN
# 14298                          NaN                    99.8
# 14299                          NaN                    90.5
#
#        Hip Circumference Comment
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 14295                        NaN
# 14296                        NaN
# 14297                        NaN
# 14298                        NaN
# 14299                        NaN
#
# [14300 rows x 22 columns]

# %%
# Count missing values for each feature (out of 14300 observations)
bmdata.isnull().sum(axis=0)
# Out:
# Respondent sequence number                 0
# Body Measures Component Status Code        0
# Weight (kg)                              225
# Weight Comment                         13712
# Recumbent Length (cm)                  12830
# Recumbent Length Comment               14257
# Head Circumference (cm)                13990
# Head Circumference Comment             14300
# Standing Height (cm)                    1143
# Standing Height Comment                14129
# Body Mass Index ($kg/m^2$)              1163
# BMI Category - Children/Youth           9551
# Upper Leg Length (cm)                   3316
# Upper Leg Length Comment               13812
# Upper Arm Length (cm)                    810
# Upper Arm Length Comment               13813
# Arm Circumference (cm)                   816
# Arm Circumference Comment              13807
# Waist Circumference (cm)                1726
# Waist Circumference Comment            13683
# Hip Circumference (cm)                  4438
# Hip Circumference Comment              13924
# dtype: int64

# %%
# Filter dataset to only include features missing less than 20% of values
bmdata2 = bmdata.dropna(axis=1, thresh=int(0.2*len(bmdata)))
bmdata2 = bmdata2.drop(['Respondent sequence number', 'Body Measures Component Status Code'], axis=1)
bmdata2
# Out:
#        Weight (kg)  Standing Height (cm)  Body Mass Index ($kg/m^2$)  \
# 0              NaN                   NaN                         NaN
# 1             42.2                 154.7                        17.6
# 2             12.0                  89.3                        15.0
# 3             97.1                 160.2                        37.8
# 4             13.6                   NaN                         NaN
# ...            ...                   ...                         ...
# 14295        108.8                 168.7                        38.2
# 14296         15.4                  93.7                        17.5
# 14297         22.9                 123.3                        15.1
# 14298         79.5                 176.4                        25.5
# 14299         59.7                 167.5                        21.3
#
#        BMI Category - Children/Youth  Upper Leg Length (cm)  \
# 0                                NaN                    NaN
# 1                                2.0                   36.3
# 2                                2.0                    NaN
# 3                                NaN                   40.8
# 4                                NaN                    NaN
# ...                              ...                    ...
# 14295                            NaN                   45.6
# 14296                            3.0                    NaN
# 14297                            2.0                    NaN
# 14298                            NaN                   42.0
# 14299                            NaN                   41.1
#
#        Upper Arm Length (cm)  Arm Circumference (cm)  \
# 0                        NaN                     NaN
# 1                       33.8                    22.7
# 2                       18.6                    14.8
# 3                       34.7                    35.8
# 4                        NaN                     NaN
# ...                      ...                     ...
# 14295                   38.6                    33.6
# 14296                   17.5                    15.8
# 14297                   24.3                    18.5
# 14298                   39.5                    31.4
# 14299                   40.3                    29.2
#
#        Waist Circumference (cm)  Hip Circumference (cm)
# 0                           NaN                     NaN
# 1                          63.8                    85.0
# 2                          41.2                     NaN
# 3                         117.9                   126.1
# 4                           NaN                     NaN
# ...                         ...                     ...
# 14295                     114.7                   118.0
# 14296                      48.4                     NaN
# 14297                      57.5                     NaN
# 14298                      97.1                    99.8
# 14299                      86.9                    90.5
#
# [14300 rows x 9 columns]

# %%
# Run correlations between all features
bmdata2.corr()
# Out:
#                                Weight (kg)  Standing Height (cm)  \
# Weight (kg)                       1.000000              0.769794
# Standing Height (cm)              0.769794              1.000000
# Body Mass Index ($kg/m^2$)        0.918685              0.497334
# BMI Category - Children/Youth     0.491157              0.173946
# Upper Leg Length (cm)             0.466561              0.819276
# Upper Arm Length (cm)             0.839773              0.959529
# Arm Circumference (cm)            0.963019              0.724401
# Waist Circumference (cm)          0.949765              0.675033
# Hip Circumference (cm)            0.880137              0.108270
#
#                                Body Mass Index ($kg/m^2$)  \
# Weight (kg)                                      0.918685
# Standing Height (cm)                             0.497334
# Body Mass Index ($kg/m^2$)                       1.000000
# BMI Category - Children/Youth                    0.719811
# Upper Leg Length (cm)                            0.157482
# Upper Arm Length (cm)                            0.585871
# Arm Circumference (cm)                           0.914158
# Waist Circumference (cm)                         0.933210
# Hip Circumference (cm)                           0.940680
#
#                                BMI Category - Children/Youth  \
# Weight (kg)                                         0.491157
# Standing Height (cm)                                0.173946
# Body Mass Index ($kg/m^2$)                          0.719811
# BMI Category - Children/Youth                       1.000000
# Upper Leg Length (cm)                               0.175764
# Upper Arm Length (cm)                               0.242624
# Arm Circumference (cm)                              0.591130
# Waist Circumference (cm)                            0.637022
# Hip Circumference (cm)                              0.782690
#
#                                Upper Leg Length (cm)  Upper Arm Length (cm)  \
# Weight (kg)                                 0.466561               0.839773
# Standing Height (cm)                        0.819276               0.959529
# Body Mass Index ($kg/m^2$)                  0.157482               0.585871
# BMI Category - Children/Youth               0.175764               0.242624
# Upper Leg Length (cm)                       1.000000               0.725441
# Upper Arm Length (cm)                       0.725441               1.000000
# Arm Circumference (cm)                      0.371979               0.820199
# Waist Circumference (cm)                    0.249853               0.741937
# Hip Circumference (cm)                      0.040081               0.318520
#
#                                Arm Circumference (cm)  \
# Weight (kg)                                  0.963019
# Standing Height (cm)                         0.724401
# Body Mass Index ($kg/m^2$)                   0.914158
# BMI Category - Children/Youth                0.591130
# Upper Leg Length (cm)                        0.371979
# Upper Arm Length (cm)                        0.820199
# Arm Circumference (cm)                       1.000000
# Waist Circumference (cm)                     0.924459
# Hip Circumference (cm)                       0.837099
#
#                                Waist Circumference (cm)  \
# Weight (kg)                                    0.949765
# Standing Height (cm)                           0.675033
# Body Mass Index ($kg/m^2$)                     0.933210
# BMI Category - Children/Youth                  0.637022
# Upper Leg Length (cm)                          0.249853
# Upper Arm Length (cm)                          0.741937
# Arm Circumference (cm)                         0.924459
# Waist Circumference (cm)                       1.000000
# Hip Circumference (cm)                         0.876384
#
#                                Hip Circumference (cm)
# Weight (kg)                                  0.880137
# Standing Height (cm)                         0.108270
# Body Mass Index ($kg/m^2$)                   0.940680
# BMI Category - Children/Youth                0.782690
# Upper Leg Length (cm)                        0.040081
# Upper Arm Length (cm)                        0.318520
# Arm Circumference (cm)                       0.837099
# Waist Circumference (cm)                     0.876384
# Hip Circumference (cm)                       1.000000

# %%
# Create heatmap
bmcorr = bmdata2.corr()
sns.set(rc={'figure.figsize':(8,8)})
ax = sns.heatmap(
    bmcorr, 
    vmin=-1, vmax=1,
    cmap='Blues',
    square=True,
    annot=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
ax.set_title('Heatmap of correlations of Body Measure data', fontsize=16)
plt.show()

# %% [markdown]
# # Blood Pressure Data

# %%
bpdata = pd.read_sas('data/P_BPXO.XPT')
bpnames = { 
    'SEQN' : 'Respondent sequence number',
    'BPAOARM' : 'Arm selected - oscillometric',
    'BPAOCSZ' :'Coded cuff size - oscillometric',
    'BPXOSY1' : 'Systolic - 1st oscillometric reading',
    'BPXODI1' : 'Diastolic - 1st oscillometric reading',
    'BPXOSY2' : 'Systolic - 2nd oscillometric reading',
    'BPXODI2' : 'Diastolic - 2nd oscillometric reading',
    'BPXOSY3' : 'Systolic - 3rd oscillometric reading',
    'BPXODI3' : 'Diastolic - 3rd oscillometric reading',
    'BPXOPLS1' : 'Pulse - 1st oscillometric reading',
    'BPXOPLS2' : 'Pulse - 2nd oscillometric reading',
    'BPXOPLS3' : 'Pulse - 3rd oscillometric reading'
}
bpdata = bpdata.rename(columns=bpnames)
bpdata
# Out:
#        Respondent sequence number Arm selected - oscillometric  \
# 0                        109264.0                         b'R'
# 1                        109266.0                         b'R'
# 2                        109270.0                         b'R'
# 3                        109271.0                         b'R'
# 4                        109273.0                         b'R'
# ...                           ...                          ...
# 11651                    124815.0                         b'R'
# 11652                    124817.0                         b'R'
# 11653                    124818.0                         b'R'
# 11654                    124821.0                         b'R'
# 11655                    124822.0                         b'R'
#
#        Coded cuff size - oscillometric  Systolic - 1st oscillometric reading  \
# 0                                  3.0                                 109.0
# 1                                  4.0                                  99.0
# 2                                  3.0                                 123.0
# 3                                  4.0                                 102.0
# 4                                  3.0                                 116.0
# ...                                ...                                   ...
# 11651                              4.0                                 141.0
# 11652                              4.0                                 111.0
# 11653                              4.0                                 106.0
# 11654                              3.0                                 121.0
# 11655                              3.0                                 122.0
#
#        Diastolic - 1st oscillometric reading  \
# 0                                       67.0
# 1                                       56.0
# 2                                       73.0
# 3                                       65.0
# 4                                       68.0
# ...                                      ...
# 11651                                   87.0
# 11652                                   69.0
# 11653                                   67.0
# 11654                                   66.0
# 11655                                   55.0
#
#        Systolic - 2nd oscillometric reading  \
# 0                                     109.0
# 1                                      99.0
# 2                                     124.0
# 3                                     108.0
# 4                                     110.0
# ...                                     ...
# 11651                                 138.0
# 11652                                 112.0
# 11653                                 108.0
# 11654                                 122.0
# 11655                                 121.0
#
#        Diastolic - 2nd oscillometric reading  \
# 0                                       68.0
# 1                                       55.0
# 2                                       77.0
# 3                                       68.0
# 4                                       66.0
# ...                                      ...
# 11651                                   86.0
# 11652                                   67.0
# 11653                                   65.0
# 11654                                   67.0
# 11655                                   56.0
#
#        Systolic - 3rd oscillometric reading  \
# 0                                     106.0
# 1                                      99.0
# 2                                     127.0
# 3                                     111.0
# 4                                     115.0
# ...                                     ...
# 11651                                 141.0
# 11652                                 113.0
# 11653                                  95.0
# 11654                                 129.0
# 11655                                 123.0
#
#        Diastolic - 3rd oscillometric reading  \
# 0                                       66.0
# 1                                       52.0
# 2                                       70.0
# 3                                       68.0
# 4                                       68.0
# ...                                      ...
# 11651                                   87.0
# 11652                                   66.0
# 11653                                   70.0
# 11654                                   67.0
# 11655                                   58.0
#
#        Pulse - 1st oscillometric reading  Pulse - 2nd oscillometric reading  \
# 0                                   94.0                               95.0
# 1                                   68.0                               66.0
# 2                                   95.0                               98.0
# 3                                   73.0                               71.0
# 4                                   71.0                               70.0
# ...                                  ...                                ...
# 11651                               56.0                               56.0
# 11652                               70.0                               70.0
# 11653                              120.0                              119.0
# 11654                               60.0                               61.0
# 11655                               56.0                               53.0
#
#        Pulse - 3rd oscillometric reading
# 0                                   91.0
# 1                                   66.0
# 2                                   93.0
# 3                                   70.0
# 4                                   70.0
# ...                                  ...
# 11651                               58.0
# 11652                               72.0
# 11653                              118.0
# 11654                               61.0
# 11655                               56.0
#
# [11656 rows x 12 columns]

# %%
bpdata2 = bpdata.drop(['Respondent sequence number', 'Arm selected - oscillometric'], axis=1)
bpdata2
# Out:
#        Coded cuff size - oscillometric  Systolic - 1st oscillometric reading  \
# 0                                  3.0                                 109.0
# 1                                  4.0                                  99.0
# 2                                  3.0                                 123.0
# 3                                  4.0                                 102.0
# 4                                  3.0                                 116.0
# ...                                ...                                   ...
# 11651                              4.0                                 141.0
# 11652                              4.0                                 111.0
# 11653                              4.0                                 106.0
# 11654                              3.0                                 121.0
# 11655                              3.0                                 122.0
#
#        Diastolic - 1st oscillometric reading  \
# 0                                       67.0
# 1                                       56.0
# 2                                       73.0
# 3                                       65.0
# 4                                       68.0
# ...                                      ...
# 11651                                   87.0
# 11652                                   69.0
# 11653                                   67.0
# 11654                                   66.0
# 11655                                   55.0
#
#        Systolic - 2nd oscillometric reading  \
# 0                                     109.0
# 1                                      99.0
# 2                                     124.0
# 3                                     108.0
# 4                                     110.0
# ...                                     ...
# 11651                                 138.0
# 11652                                 112.0
# 11653                                 108.0
# 11654                                 122.0
# 11655                                 121.0
#
#        Diastolic - 2nd oscillometric reading  \
# 0                                       68.0
# 1                                       55.0
# 2                                       77.0
# 3                                       68.0
# 4                                       66.0
# ...                                      ...
# 11651                                   86.0
# 11652                                   67.0
# 11653                                   65.0
# 11654                                   67.0
# 11655                                   56.0
#
#        Systolic - 3rd oscillometric reading  \
# 0                                     106.0
# 1                                      99.0
# 2                                     127.0
# 3                                     111.0
# 4                                     115.0
# ...                                     ...
# 11651                                 141.0
# 11652                                 113.0
# 11653                                  95.0
# 11654                                 129.0
# 11655                                 123.0
#
#        Diastolic - 3rd oscillometric reading  \
# 0                                       66.0
# 1                                       52.0
# 2                                       70.0
# 3                                       68.0
# 4                                       68.0
# ...                                      ...
# 11651                                   87.0
# 11652                                   66.0
# 11653                                   70.0
# 11654                                   67.0
# 11655                                   58.0
#
#        Pulse - 1st oscillometric reading  Pulse - 2nd oscillometric reading  \
# 0                                   94.0                               95.0
# 1                                   68.0                               66.0
# 2                                   95.0                               98.0
# 3                                   73.0                               71.0
# 4                                   71.0                               70.0
# ...                                  ...                                ...
# 11651                               56.0                               56.0
# 11652                               70.0                               70.0
# 11653                              120.0                              119.0
# 11654                               60.0                               61.0
# 11655                               56.0                               53.0
#
#        Pulse - 3rd oscillometric reading
# 0                                   91.0
# 1                                   66.0
# 2                                   93.0
# 3                                   70.0
# 4                                   70.0
# ...                                  ...
# 11651                               58.0
# 11652                               72.0
# 11653                              118.0
# 11654                               61.0
# 11655                               56.0
#
# [11656 rows x 10 columns]

# %%
# Mean values of each feature
bpdata2.mean()
# Out:
# Coded cuff size - oscillometric            3.501301
# Systolic - 1st oscillometric reading     120.004637
# Diastolic - 1st oscillometric reading     72.035742
# Systolic - 2nd oscillometric reading     119.732255
# Diastolic - 2nd oscillometric reading     71.503825
# Systolic - 3rd oscillometric reading     119.681898
# Diastolic - 3rd oscillometric reading     71.258798
# Pulse - 1st oscillometric reading         71.183824
# Pulse - 2nd oscillometric reading         71.946655
# Pulse - 3rd oscillometric reading         72.550892
# dtype: float64

# %%
# Correlations
bpdata2.corr()
# Out:
#                                        Coded cuff size - oscillometric  \
# Coded cuff size - oscillometric                               1.000000
# Systolic - 1st oscillometric reading                          0.170994
# Diastolic - 1st oscillometric reading                         0.337639
# Systolic - 2nd oscillometric reading                          0.173627
# Diastolic - 2nd oscillometric reading                         0.339366
# Systolic - 3rd oscillometric reading                          0.178986
# Diastolic - 3rd oscillometric reading                         0.342106
# Pulse - 1st oscillometric reading                            -0.081276
# Pulse - 2nd oscillometric reading                            -0.093032
# Pulse - 3rd oscillometric reading                            -0.107940
#
#                                        Systolic - 1st oscillometric reading  \
# Coded cuff size - oscillometric                                    0.170994
# Systolic - 1st oscillometric reading                               1.000000
# Diastolic - 1st oscillometric reading                              0.674561
# Systolic - 2nd oscillometric reading                               0.950386
# Diastolic - 2nd oscillometric reading                              0.637523
# Systolic - 3rd oscillometric reading                               0.939808
# Diastolic - 3rd oscillometric reading                              0.626704
# Pulse - 1st oscillometric reading                                 -0.148800
# Pulse - 2nd oscillometric reading                                 -0.178041
# Pulse - 3rd oscillometric reading                                 -0.192196
#
#                                        Diastolic - 1st oscillometric reading  \
# Coded cuff size - oscillometric                                     0.337639
# Systolic - 1st oscillometric reading                                0.674561
# Diastolic - 1st oscillometric reading                               1.000000
# Systolic - 2nd oscillometric reading                                0.666899
# Diastolic - 2nd oscillometric reading                               0.911813
# Systolic - 3rd oscillometric reading                                0.665763
# Diastolic - 3rd oscillometric reading                               0.902653
# Pulse - 1st oscillometric reading                                   0.093274
# Pulse - 2nd oscillometric reading                                   0.059821
# Pulse - 3rd oscillometric reading                                   0.043317
#
#                                        Systolic - 2nd oscillometric reading  \
# Coded cuff size - oscillometric                                    0.173627
# Systolic - 1st oscillometric reading                               0.950386
# Diastolic - 1st oscillometric reading                              0.666899
# Systolic - 2nd oscillometric reading                               1.000000
# Diastolic - 2nd oscillometric reading                              0.667103
# Systolic - 3rd oscillometric reading                               0.947402
# Diastolic - 3rd oscillometric reading                              0.639702
# Pulse - 1st oscillometric reading                                 -0.156230
# Pulse - 2nd oscillometric reading                                 -0.187728
# Pulse - 3rd oscillometric reading                                 -0.202350
#
#                                        Diastolic - 2nd oscillometric reading  \
# Coded cuff size - oscillometric                                     0.339366
# Systolic - 1st oscillometric reading                                0.637523
# Diastolic - 1st oscillometric reading                               0.911813
# Systolic - 2nd oscillometric reading                                0.667103
# Diastolic - 2nd oscillometric reading                               1.000000
# Systolic - 3rd oscillometric reading                                0.652814
# Diastolic - 3rd oscillometric reading                               0.913515
# Pulse - 1st oscillometric reading                                   0.084373
# Pulse - 2nd oscillometric reading                                   0.075841
# Pulse - 3rd oscillometric reading                                   0.050857
#
#                                        Systolic - 3rd oscillometric reading  \
# Coded cuff size - oscillometric                                    0.178986
# Systolic - 1st oscillometric reading                               0.939808
# Diastolic - 1st oscillometric reading                              0.665763
# Systolic - 2nd oscillometric reading                               0.947402
# Diastolic - 2nd oscillometric reading                              0.652814
# Systolic - 3rd oscillometric reading                               1.000000
# Diastolic - 3rd oscillometric reading                              0.665918
# Pulse - 1st oscillometric reading                                 -0.151713
# Pulse - 2nd oscillometric reading                                 -0.180711
# Pulse - 3rd oscillometric reading                                 -0.195566
#
#                                        Diastolic - 3rd oscillometric reading  \
# Coded cuff size - oscillometric                                     0.342106
# Systolic - 1st oscillometric reading                                0.626704
# Diastolic - 1st oscillometric reading                               0.902653
# Systolic - 2nd oscillometric reading                                0.639702
# Diastolic - 2nd oscillometric reading                               0.913515
# Systolic - 3rd oscillometric reading                                0.665918
# Diastolic - 3rd oscillometric reading                               1.000000
# Pulse - 1st oscillometric reading                                   0.084125
# Pulse - 2nd oscillometric reading                                   0.070231
# Pulse - 3rd oscillometric reading                                   0.067364
#
#                                        Pulse - 1st oscillometric reading  \
# Coded cuff size - oscillometric                                -0.081276
# Systolic - 1st oscillometric reading                           -0.148800
# Diastolic - 1st oscillometric reading                           0.093274
# Systolic - 2nd oscillometric reading                           -0.156230
# Diastolic - 2nd oscillometric reading                           0.084373
# Systolic - 3rd oscillometric reading                           -0.151713
# Diastolic - 3rd oscillometric reading                           0.084125
# Pulse - 1st oscillometric reading                               1.000000
# Pulse - 2nd oscillometric reading                               0.942628
# Pulse - 3rd oscillometric reading                               0.933090
#
#                                        Pulse - 2nd oscillometric reading  \
# Coded cuff size - oscillometric                                -0.093032
# Systolic - 1st oscillometric reading                           -0.178041
# Diastolic - 1st oscillometric reading                           0.059821
# Systolic - 2nd oscillometric reading                           -0.187728
# Diastolic - 2nd oscillometric reading                           0.075841
# Systolic - 3rd oscillometric reading                           -0.180711
# Diastolic - 3rd oscillometric reading                           0.070231
# Pulse - 1st oscillometric reading                               0.942628
# Pulse - 2nd oscillometric reading                               1.000000
# Pulse - 3rd oscillometric reading                               0.942932
#
#                                        Pulse - 3rd oscillometric reading
# Coded cuff size - oscillometric                                -0.107940
# Systolic - 1st oscillometric reading                           -0.192196
# Diastolic - 1st oscillometric reading                           0.043317
# Systolic - 2nd oscillometric reading                           -0.202350
# Diastolic - 2nd oscillometric reading                           0.050857
# Systolic - 3rd oscillometric reading                           -0.195566
# Diastolic - 3rd oscillometric reading                           0.067364
# Pulse - 1st oscillometric reading                               0.933090
# Pulse - 2nd oscillometric reading                               0.942932
# Pulse - 3rd oscillometric reading                               1.000000

# %%
# Correlation heatmap
bpcorr = bpdata2.corr()
sns.set(rc={'figure.figsize':(8,8)})
ax2 = sns.heatmap(
    bpcorr, 
    vmin=-1, vmax=1,
    cmap='Blues',
    square=True,
    annot=True
)
ax2.set_xticklabels(
    ax2.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
ax2.set_title('Heatmap of correlations of Blood Pressure data', fontsize=16)
plt.show()

# %%
# Histogram of blood pressure values
for i in ['Systolic - 1st oscillometric reading',
          'Systolic - 2nd oscillometric reading',
          'Systolic - 3rd oscillometric reading']:
    plt.hist(bpdata2[i], bins=100, label=i)
plt.title('Distribution of sequential systolic BP readings', fontsize=16)

# Optionally add references points for BP thresholds [1]:
plt.axvline(x=120,color='k', linestyle='--', label='Healthy/At-risk')
plt.axvline(x=135,color='k', linestyle='-', label='At-risk/High')

plt.legend()
plt.show()

# %%
for i in ['Diastolic - 1st oscillometric reading',
          'Diastolic - 2nd oscillometric reading',
          'Diastolic - 3rd oscillometric reading']:
    plt.hist(bpdata2[i], bins=100, label=i)
plt.title('Distribution of sequential diastolic BP readings', fontsize=16)

# Optionally add references points for BP thresholds [1]:
plt.axvline(x=80,color='k', linestyle='--', label='Healthy/At-risk')
plt.axvline(x=85,color='k', linestyle='-', label='At-risk/High')

plt.legend()
plt.show()

# %%
for i in ['Pulse - 1st oscillometric reading',
          'Pulse - 2nd oscillometric reading',
          'Pulse - 3rd oscillometric reading']:
    plt.hist(bpdata2[i], bins=100, label=i)
plt.title('Distribution of sequential HR readings', fontsize=16)
plt.legend()
plt.show()

# %% [markdown]
# ## References
# 1. https://www.heartandstroke.ca/-/media/pdf-files/canada/health-information-catalogue/en-managing-your-blood-pressure.ashx
