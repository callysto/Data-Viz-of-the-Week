# %%
import pandas as pd
gas_df = pd.read_csv('GasPricesLoad.csv')
gas_df
# Out:
#    REF_DATE                                 GEO             DGUID  \
# 0   2021-11                              Canada    2016A000011124
# 1   2021-12                              Canada    2016A000011124
# 2   2022-01                              Canada    2016A000011124
# 3   2022-02                              Canada    2016A000011124
# 4   2022-03                              Canada    2016A000011124
# ..      ...                                 ...               ...
# 90  2021-11  Yellowknife, Northwest Territories  2011A00056106023
# 91  2021-12  Yellowknife, Northwest Territories  2011A00056106023
# 92  2022-01  Yellowknife, Northwest Territories  2011A00056106023
# 93  2022-02  Yellowknife, Northwest Territories  2011A00056106023
# 94  2022-03  Yellowknife, Northwest Territories  2011A00056106023
#
#                                          Type of fuel              UOM  \
# 0   Regular unleaded gasoline at self service fill...  Cents per litre
# ...

# %%
len(gas_df)
# Out:
# 95

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install pandas-datareader
# Out:
# ...
#   Using cached pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas_datareader as pdr

# %%
plt.scatter(gas_df.REF_DATE, gas_df.VALUE)
plt.grid()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns  # for sample data
from matplotlib.lines import Line2D  # for legend handle

# %%
plt.scatter(x = 'REF_DATE', y = 'VALUE', data = gas_df, c = 'GEO')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4349             try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4350                 colors = mcolors.to_rgba_array(c)
#    4351             except (TypeError, ValueError) as err:
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     384     else:
# --> 385         rgba = np.array([to_rgba(cc) for cc in c])
#     386
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/colors.py in <listcomp>(.0)
#     384     else:
# --> 385         rgba = np.array([to_rgba(cc) for cc in c])
#     386
#
# /opt/conda/lib/python3.9/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
# ...

# %%
categorical_df = gas_df.groupby('GEO').count()
categorical_df
# Out:
#                                                     REF_DATE  DGUID  \
# GEO
# Calgary, Alberta                                           5      5
# Canada                                                     5      5
# Charlottetown and Summerside, Prince Edward Island         5      0
# Edmonton, Alberta                                          5      5
# Halifax, Nova Scotia                                       5      5
# Montréal, Quebec                                           5      5
# Ottawa-Gatineau, Ontario part, Ontario/Quebec              5      5
# Québec, Quebec                                             5      5
# Regina, Saskatchewan                                       5      5
# Saint John, New Brunswick                                  5      5
# Saskatoon, Saskatchewan                                    5      5
# St. John's, Newfoundland and Labrador                      5      5
# Thunder Bay, Ontario                                       5      5
# ...

# %%
newgas_df = pd.read_csv("1990to2021.csv")
newgas_df.head(5)
# Out:
#   REF_DATE     GEO           DGUID  \
# 0  2006-01  Canada  2016A000011124
# 1  2006-02  Canada  2016A000011124
# 2  2006-03  Canada  2016A000011124
# 3  2006-04  Canada  2016A000011124
# 4  2006-05  Canada  2016A000011124
#
#                                         Type of fuel              UOM  UOM_ID  \
# 0  Regular unleaded gasoline at self service fill...  Cents per litre      57
# 1  Regular unleaded gasoline at self service fill...  Cents per litre      57
# 2  Regular unleaded gasoline at self service fill...  Cents per litre      57
# 3  Regular unleaded gasoline at self service fill...  Cents per litre      57
# 4  Regular unleaded gasoline at self service fill...  Cents per litre      57
#
#   SCALAR_FACTOR  SCALAR_ID       VECTOR  COORDINATE  VALUE  STATUS  SYMBOL  \
# 0         units          0  v1352087861        20.2   95.0     NaN     NaN
# 1         units          0  v1352087861        20.2   88.0     NaN     NaN
# ...

# %%
import select
#df.loc[df.index.map(crit)]
# newgas_df.select('REF_DATE', 'GEO', 'VALUE')
# newnew = type(newgas_df['REF_DATE','GEO', 'VALUE'])
newnew = newgas_df[['REF_DATE','GEO', 'VALUE']]
newnew
# newnew = newgas_df(typ)'REF_DATE','GEO', 'VALUE']
# Out:
#      REF_DATE                                 GEO  VALUE
# 0     2006-01                              Canada   95.0
# 1     2006-02                              Canada   88.0
# 2     2006-03                              Canada   93.3
# 3     2006-04                              Canada  106.2
# 4     2006-05                              Canada  104.6
# ...       ...                                 ...    ...
# 7096  2021-11  Yellowknife, Northwest Territories  152.8
# 7097  2021-12  Yellowknife, Northwest Territories  151.5
# 7098  2022-01  Yellowknife, Northwest Territories  151.5
# 7099  2022-02  Yellowknife, Northwest Territories  158.1
# 7100  2022-03  Yellowknife, Northwest Territories  175.6
#
# [7101 rows x 3 columns]

# %%
categorical_df2 = newnew.groupby('GEO').sum('VALUE')
categorical_df2
# Out:
#                                                       VALUE
# GEO
# Calgary, Alberta                                    31615.8
# Canada                                              22190.2
# Charlottetown and Summerside, Prince Edward Island  34568.5
# Edmonton, Alberta                                   30743.5
# Halifax, Nova Scotia                                33365.4
# Montréal, Quebec                                    36435.7
# Ottawa-Gatineau, Ontario part, Ontario/Quebec       33534.8
# Québec, Quebec                                      35935.4
# Regina, Saskatchewan                                33644.3
# Saint John, New Brunswick                           32537.2
# Saskatoon, Saskatchewan                             33846.9
# St. John's, Newfoundland and Labrador               37298.6
# Thunder Bay, Ontario                                36104.0
# Toronto, Ontario                                    33789.9
# Vancouver, British Columbia                         37565.7
# ...

# %%
categorical_df3 = newnew.groupby(['GEO', 'REF_DATE']).sum('VALUE')
categorical_df3
# Out:
#                                              VALUE
# GEO                                REF_DATE
# Calgary, Alberta                   1990-01    47.9
#                                    1990-02    48.9
#                                    1990-03    49.7
#                                    1990-04    51.9
#                                    1990-05    51.9
# ...                                            ...
# Yellowknife, Northwest Territories 2021-11   152.8
#                                    2021-12   151.5
#                                    2022-01   151.5
#                                    2022-02   158.1
#                                    2022-03   175.6
#
# [7101 rows x 1 columns]

# %%
oilGasDataType = categorical_df3.dtypes
oilGasDataType
# Out:
# VALUE    float64
# dtype: object

# %%
newgas_df.dtypes
# Out:
# REF_DATE          object
# GEO               object
# DGUID             object
# Type of fuel      object
# UOM               object
# UOM_ID             int64
# SCALAR_FACTOR     object
# SCALAR_ID          int64
# VECTOR            object
# COORDINATE       float64
# VALUE            float64
# STATUS           float64
# SYMBOL           float64
# TERMINATED       float64
# DECIMALS           int64
# dtype: object

# %%
newnew.dtypes
# Out:
# REF_DATE     object
# GEO          object
# VALUE       float64
# dtype: object

# %%
newnew[newnew['REF_DATE'].str.contains('1990')]
# Out:
#      REF_DATE                                    GEO  VALUE
# 195   1990-01  St. John's, Newfoundland and Labrador   57.7
# 196   1990-02  St. John's, Newfoundland and Labrador   58.2
# 197   1990-03  St. John's, Newfoundland and Labrador   58.5
# 198   1990-04  St. John's, Newfoundland and Labrador   59.3
# 199   1990-05  St. John's, Newfoundland and Labrador   59.8
# ...       ...                                    ...    ...
# 6721  1990-08     Yellowknife, Northwest Territories   61.7
# 6722  1990-09     Yellowknife, Northwest Territories   63.1
# 6723  1990-10     Yellowknife, Northwest Territories   70.2
# 6724  1990-11     Yellowknife, Northwest Territories   72.8
# 6725  1990-12     Yellowknife, Northwest Territories   74.3
#
# [192 rows x 3 columns]

# %%
datenew =newnew.REF_DATE.str.split(pat='-',expand=True)
datenew.columns = ['Year', 'Month']
datenew
# Out:
#       Year Month
# 0     2006    01
# 1     2006    02
# 2     2006    03
# 3     2006    04
# 4     2006    05
# ...    ...   ...
# 7096  2021    11
# 7097  2021    12
# 7098  2022    01
# 7099  2022    02
# 7100  2022    03
#
# [7101 rows x 2 columns]

# %%
datenew.columns
datenew.head(5)
# Out:
#    Year Month
# 0  2006    01
# 1  2006    02
# 2  2006    03
# 3  2006    04
# 4  2006    05

# %%
del datenew['Month']

# %%
frames = [datenew, newnew]

# %%
datenew.head(5)
# Out:
#    Year
# 0  2006
# 1  2006
# 2  2006
# 3  2006
# 4  2006

# %%
newnew.head(10)
# Out:
#   REF_DATE     GEO  VALUE
# 0  2006-01  Canada   95.0
# 1  2006-02  Canada   88.0
# 2  2006-03  Canada   93.3
# 3  2006-04  Canada  106.2
# 4  2006-05  Canada  104.6
# 5  2006-06  Canada  104.5
# 6  2006-07  Canada  109.7
# 7  2006-08  Canada  109.6
# 8  2006-09  Canada   89.7
# 9  2006-10  Canada   86.5

# %%
datenew.head(10)
# Out:
#    Year
# 0  2006
# 1  2006
# 2  2006
# 3  2006
# 4  2006
# 5  2006
# 6  2006
# 7  2006
# 8  2006
# 9  2006

# %%
finalframe = pd.concat([datenew, newnew], axis=1)
finalframe
# Out:
#       Year REF_DATE                                 GEO  VALUE
# 0     2006  2006-01                              Canada   95.0
# 1     2006  2006-02                              Canada   88.0
# 2     2006  2006-03                              Canada   93.3
# 3     2006  2006-04                              Canada  106.2
# 4     2006  2006-05                              Canada  104.6
# ...    ...      ...                                 ...    ...
# 7096  2021  2021-11  Yellowknife, Northwest Territories  152.8
# 7097  2021  2021-12  Yellowknife, Northwest Territories  151.5
# 7098  2022  2022-01  Yellowknife, Northwest Territories  151.5
# 7099  2022  2022-02  Yellowknife, Northwest Territories  158.1
# 7100  2022  2022-03  Yellowknife, Northwest Territories  175.6
#
# [7101 rows x 4 columns]

# %%
del finalframe['REF_DATE']

# %%
finalframe.head(6)
# Out:
#    Year     GEO  VALUE
# 0  2006  Canada   95.0
# 1  2006  Canada   88.0
# 2  2006  Canada   93.3
# 3  2006  Canada  106.2
# 4  2006  Canada  104.6
# 5  2006  Canada  104.5

# %%
finalframe
# Out:
#       Year                                 GEO  VALUE
# 0     2006                              Canada   95.0
# 1     2006                              Canada   88.0
# 2     2006                              Canada   93.3
# 3     2006                              Canada  106.2
# 4     2006                              Canada  104.6
# ...    ...                                 ...    ...
# 7096  2021  Yellowknife, Northwest Territories  152.8
# 7097  2021  Yellowknife, Northwest Territories  151.5
# 7098  2022  Yellowknife, Northwest Territories  151.5
# 7099  2022  Yellowknife, Northwest Territories  158.1
# 7100  2022  Yellowknife, Northwest Territories  175.6
#
# [7101 rows x 3 columns]

# %%
recell = newnew.groupby(['GEO'])
recell

# %%
newfinal = finalframe.groupby(['GEO', 'Year'], as_index=False).sum('VALUE')
newfinal
# Out:
#                                     GEO  Year   VALUE
# 0                      Calgary, Alberta  1990   649.8
# 1                      Calgary, Alberta  1991   605.9
# 2                      Calgary, Alberta  1992   559.2
# 3                      Calgary, Alberta  1993   567.7
# 4                      Calgary, Alberta  1994   569.3
# ..                                  ...   ...     ...
# 602  Yellowknife, Northwest Territories  2018  1628.3
# 603  Yellowknife, Northwest Territories  2019  1578.0
# 604  Yellowknife, Northwest Territories  2020  1377.1
# 605  Yellowknife, Northwest Territories  2021  1698.0
# 606  Yellowknife, Northwest Territories  2022   485.2
#
# [607 rows x 3 columns]

# %%
newfinal = finalframe.groupby(['GEO', 'Year'], as_index=False).sum('VALUE')

# %%
transpose = newfinal.T
transpose
# Out:
#                     0                 1                 2                 3    \
# GEO    Calgary, Alberta  Calgary, Alberta  Calgary, Alberta  Calgary, Alberta
# Year               1990              1991              1992              1993
# VALUE             649.8             605.9             559.2             567.7
#
#                     4                 5                 6                 7    \
# GEO    Calgary, Alberta  Calgary, Alberta  Calgary, Alberta  Calgary, Alberta
# Year               1994              1995              1996              1997
# VALUE             569.3             599.8             620.2             637.8
#
#                     8                 9    ...  \
# GEO    Calgary, Alberta  Calgary, Alberta  ...
# Year               1998              1999  ...
# VALUE             586.4             631.8  ...
#
#                                       597                                 598  \
# ...

# %%
newnew.head(3)
# Out:
#   REF_DATE     GEO  VALUE
# 0  2006-01  Canada   95.0
# 1  2006-02  Canada   88.0
# 2  2006-03  Canada   93.3

# %%
newgas_df.head(5)
# Out:
#   REF_DATE     GEO           DGUID  \
# 0  2006-01  Canada  2016A000011124
# 1  2006-02  Canada  2016A000011124
# 2  2006-03  Canada  2016A000011124
# 3  2006-04  Canada  2016A000011124
# 4  2006-05  Canada  2016A000011124
#
#                                         Type of fuel              UOM  UOM_ID  \
# 0  Regular unleaded gasoline at self service fill...  Cents per litre      57
# 1  Regular unleaded gasoline at self service fill...  Cents per litre      57
# 2  Regular unleaded gasoline at self service fill...  Cents per litre      57
# 3  Regular unleaded gasoline at self service fill...  Cents per litre      57
# 4  Regular unleaded gasoline at self service fill...  Cents per litre      57
#
#   SCALAR_FACTOR  SCALAR_ID       VECTOR  COORDINATE  VALUE  STATUS  SYMBOL  \
# 0         units          0  v1352087861        20.2   95.0     NaN     NaN
# 1         units          0  v1352087861        20.2   88.0     NaN     NaN
# ...

# %%
import geopandas as gp

# %%
gastry = newgas_df.set_index(['REF_DATE'])
gastry
# Out:
#                                          GEO             DGUID  \
# REF_DATE
# 2006-01                               Canada    2016A000011124
# 2006-02                               Canada    2016A000011124
# 2006-03                               Canada    2016A000011124
# 2006-04                               Canada    2016A000011124
# 2006-05                               Canada    2016A000011124
# ...                                      ...               ...
# 2021-11   Yellowknife, Northwest Territories  2011A00056106023
# 2021-12   Yellowknife, Northwest Territories  2011A00056106023
# 2022-01   Yellowknife, Northwest Territories  2011A00056106023
# 2022-02   Yellowknife, Northwest Territories  2011A00056106023
# 2022-03   Yellowknife, Northwest Territories  2011A00056106023
#
#                                                Type of fuel              UOM  \
# REF_DATE
# 2006-01   Regular unleaded gasoline at self service fill...  Cents per litre
# ...

# %%
gastry.columns
# Out:
# Index(['GEO', 'DGUID', 'Type of fuel', 'UOM', 'UOM_ID', 'SCALAR_FACTOR',
#        'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL',
#        'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
gasgas = gastry[['GEO', 'VALUE']]
gasgas
# Out:
#                                          GEO  VALUE
# REF_DATE
# 2006-01                               Canada   95.0
# 2006-02                               Canada   88.0
# 2006-03                               Canada   93.3
# 2006-04                               Canada  106.2
# 2006-05                               Canada  104.6
# ...                                      ...    ...
# 2021-11   Yellowknife, Northwest Territories  152.8
# 2021-12   Yellowknife, Northwest Territories  151.5
# 2022-01   Yellowknife, Northwest Territories  151.5
# 2022-02   Yellowknife, Northwest Territories  158.1
# 2022-03   Yellowknife, Northwest Territories  175.6
#
# [7101 rows x 2 columns]

# %%
gas3 = gasgas.pivot(columns = 'GEO')
gas3
gas3.head(60)
# Out:
#                     VALUE         \
# GEO      Calgary, Alberta Canada
# REF_DATE
# 1990-01              47.9    NaN
# 1990-02              48.9    NaN
# 1990-03              49.7    NaN
# 1990-04              51.9    NaN
# 1990-05              51.9    NaN
# 1990-06              53.4    NaN
# 1990-07              53.0    NaN
# 1990-08              53.4    NaN
# 1990-09              54.9    NaN
# 1990-10              61.4    NaN
# 1990-11              62.8    NaN
# 1990-12              60.6    NaN
# 1991-01              63.5    NaN
# 1991-02              44.9    NaN
# 1991-03              45.5    NaN
# 1991-04              42.8    NaN
# 1991-05              49.3    NaN
# 1991-06              48.8    NaN
# 1991-07              52.9    NaN
# 1991-08              54.1    NaN
# 1991-09              54.9    NaN
# 1991-10              50.9    NaN
# 1991-11              48.7    NaN
# 1991-12              49.6    NaN
# 1992-01              46.1    NaN
# 1992-02              44.0    NaN
# ...

# %%
gas3.columns
# Out:
# MultiIndex([('VALUE',                                   'Calgary, Alberta'),
#             ('VALUE',                                             'Canada'),
#             ('VALUE', 'Charlottetown and Summerside, Prince Edward Island'),
#             ('VALUE',                                  'Edmonton, Alberta'),
#             ('VALUE',                               'Halifax, Nova Scotia'),
#             ('VALUE',                                   'Montréal, Quebec'),
#             ('VALUE',      'Ottawa-Gatineau, Ontario part, Ontario/Quebec'),
#             ('VALUE',                                     'Québec, Quebec'),
#             ('VALUE',                               'Regina, Saskatchewan'),
#             ('VALUE',                          'Saint John, New Brunswick'),
#             ('VALUE',                            'Saskatoon, Saskatchewan'),
#             ('VALUE',              'St. John's, Newfoundland and Labrador'),
# ...

# %%
gas3.columns = gas3.columns.droplevel()

# %%
gas3.head(10)
# Out:
# GEO       Calgary, Alberta  Canada  \
# REF_DATE
# 1990-01               47.9     NaN
# 1990-02               48.9     NaN
# 1990-03               49.7     NaN
# 1990-04               51.9     NaN
# 1990-05               51.9     NaN
# 1990-06               53.4     NaN
# 1990-07               53.0     NaN
# 1990-08               53.4     NaN
# 1990-09               54.9     NaN
# 1990-10               61.4     NaN
#
# GEO       Charlottetown and Summerside, Prince Edward Island  \
# REF_DATE
# 1990-01                                                54.6
# 1990-02                                                54.8
# 1990-03                                                55.0
# 1990-04                                                56.4
# 1990-05                                                56.8
# 1990-06                                                57.4
# 1990-07                                                58.5
# 1990-08                                                58.6
# ...

# %%
gas2 = newgas_df.groupby(['REF_DATE'])

gas2.head(60)
gas2.set_index(['REF_DATE'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_36/2780179164.py in <module>
#       2
#       3 gas2.head(60)
# ----> 4 gas2.set_index(['REF_DATE'])
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     909             return self[attr]
#     910
# --> 911         raise AttributeError(
#     912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'set_index'

# %%
del gas3['Canada']

# %%
gas3.head(10)
# Out:
# GEO       Calgary, Alberta  \
# REF_DATE
# 1990-01               47.9
# 1990-02               48.9
# 1990-03               49.7
# 1990-04               51.9
# 1990-05               51.9
# 1990-06               53.4
# 1990-07               53.0
# 1990-08               53.4
# 1990-09               54.9
# 1990-10               61.4
#
# GEO       Charlottetown and Summerside, Prince Edward Island  \
# REF_DATE
# 1990-01                                                54.6
# 1990-02                                                54.8
# 1990-03                                                55.0
# 1990-04                                                56.4
# 1990-05                                                56.8
# 1990-06                                                57.4
# 1990-07                                                58.5
# 1990-08                                                58.6
# 1990-09                                                58.6
# ...

# %%
finalGas = gas3

# %%
gasplot = gas3.plot(y = ['Calgary, Alberta', 'Vancouver, British Columbia'], use_index = True, figsize = (8,8))

# %%
gasT = gasgas.T
gasT
# Out:
# REF_DATE 2006-01 2006-02 2006-03 2006-04 2006-05 2006-06 2006-07 2006-08  \
# GEO       Canada  Canada  Canada  Canada  Canada  Canada  Canada  Canada
# VALUE       95.0    88.0    93.3   106.2   104.6   104.5   109.7   109.6
#
# REF_DATE 2006-09 2006-10  ...                             2021-06  \
# GEO       Canada  Canada  ...  Yellowknife, Northwest Territories
# VALUE       89.7    86.5  ...                               143.1
#
# REF_DATE                             2021-07  \
# GEO       Yellowknife, Northwest Territories
# VALUE                                  147.6
#
# REF_DATE                             2021-08  \
# GEO       Yellowknife, Northwest Territories
# VALUE                                  149.8
#
# REF_DATE                             2021-09  \
# GEO       Yellowknife, Northwest Territories
# VALUE                                  149.9
#
# REF_DATE                             2021-10  \
# GEO       Yellowknife, Northwest Territories
# ...

# %%
df1= pd.pivot_table(gasgas, index=['REF_DATE'], values=['VALUE'])
df1
# Out:
#                VALUE
# REF_DATE
# 1990-01    54.575000
# 1990-02    55.106250
# 1990-03    55.793750
# 1990-04    56.500000
# 1990-05    56.956250
# ...              ...
# 2021-11   148.015789
# 2021-12   141.615789
# 2022-01   147.842105
# 2022-02   157.247368
# 2022-03   176.505263
#
# [387 rows x 1 columns]

# %%
help(gp)
# Out:
# Help on package geopandas:
#
# NAME
#     geopandas
#
# PACKAGE CONTENTS
#     _compat
#     _config
#     _vectorized
#     _version
#     array
#     base
#     conftest
#     datasets (package)
#     geodataframe
#     geoseries
#     io (package)
#     plotting
#     sindex
#     testing
#     tests (package)
#     tools (package)
#
# DATA
#     options = Options(
#       display_precision: None [default: Non...USE_PYGEO...
#
# VERSION
#     0.9.0
#
# FILE
#     /opt/conda/lib/python3.9/site-packages/geopandas/__init__.py

# %%
import pathlib
import plotly.express as px

# %%
# # import xarray as xr 
# import numpy as np
# # import regionmask
# import geopandas as gpd
# import pandas as pd
# import matplotlib.pyplot as plt
# from osgeo import ogr
# import warnings; warnings.filterwarnings(action='ignore')

# %%
PATH_TO_SHAPEFILE = "lpr_000b16a_e.shp"
province = gp.read_file(PATH_TO_SHAPEFILE)
province
# Out:
#    PRUID                                             PRNAME  \
# 0     10  Newfoundland and Labrador / Terre-Neuve-et-Lab...
# 1     11       Prince Edward Island / Île-du-Prince-Édouard
# 2     12                      Nova Scotia / Nouvelle-Écosse
# 3     13                  New Brunswick / Nouveau-Brunswick
# 4     24                                    Quebec / Québec
# 5     35                                            Ontario
# 6     46                                           Manitoba
# 7     47                                       Saskatchewan
# 8     48                                            Alberta
# 9     59            British Columbia / Colombie-Britannique
# 10    60                                              Yukon
# 11    61  Northwest Territories / Territoires du Nord-Ouest
# 12    62                                            Nunavut
#
#                       PRENAME                    PRFNAME PREABBR   PRFABBR  \
# ...

# %%
gasT
# Out:
# REF_DATE 2006-01 2006-02 2006-03 2006-04 2006-05 2006-06 2006-07 2006-08  \
# GEO       Canada  Canada  Canada  Canada  Canada  Canada  Canada  Canada
# VALUE       95.0    88.0    93.3   106.2   104.6   104.5   109.7   109.6
#
# REF_DATE 2006-09 2006-10  ...                             2021-06  \
# GEO       Canada  Canada  ...  Yellowknife, Northwest Territories
# VALUE       89.7    86.5  ...                               143.1
#
# REF_DATE                             2021-07  \
# GEO       Yellowknife, Northwest Territories
# VALUE                                  147.6
#
# REF_DATE                             2021-08  \
# GEO       Yellowknife, Northwest Territories
# VALUE                                  149.8
#
# REF_DATE                             2021-09  \
# GEO       Yellowknife, Northwest Territories
# VALUE                                  149.9
#
# REF_DATE                             2021-10  \
# GEO       Yellowknife, Northwest Territories
# ...

# %%
PATH_TO_SHAPEFILE2 = "CAN_ADM1.shp"
province2 = gp.read_file(PATH_TO_SHAPEFILE2)
province2
# Out:
#    ISO_Code Level                       Name   adm  adm_int feature_id  \
# 0     CA-NL  ADM1  Newfoundland and Labrador  ADM1        1          0
# 1     CA-PE  ADM1       Prince Edward Island  ADM1        1          1
# 2     CA-NS  ADM1                Nova Scotia  ADM1        1          2
# 3     CA-NB  ADM1              New Brunswick  ADM1        1          3
# 4     CA-QC  ADM1                     Quebec  ADM1        1          4
# 5     CA-ON  ADM1                    Ontario  ADM1        1          5
# 6     CA-MB  ADM1                   Manitoba  ADM1        1          6
# 7     CA-SK  ADM1               Saskatchewan  ADM1        1          7
# 8     CA-AB  ADM1                    Alberta  ADM1        1          8
# 9     CA-BC  ADM1           British Columbia  ADM1        1          9
# 10    CA-YT  ADM1                      Yukon  ADM1        1         10
# 11    CA-NT  ADM1      Northwest Territories  ADM1        1         11
# ...

# %%
province2.plot(cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
majCity = gp.read_file("maj_cities_ca.shp")
majCity
# Out:
#     ObjectID          NAME PROV CAPITAL   POP_RANK  PREC_CODE  PRCDCSD  \
# 0          1       Calgary   AB       N  > 100,000          2  4806016
# 1          7    Lethbridge   AB       N  < 100,000          1  4802012
# 2          9  Medicine Hat   AB       N  < 100,000          2  4801006
# 3         14       Airdrie   AB       N  < 100,000          2  4806021
# 4         15    Drumheller   AB       N  < 100,000          2  4805026
# 5         19     Castlegar   BC       N  < 100,000          2  5903045
# 6         24     Cranbrook   BC       N  < 100,000          2  5901022
# 7         28        Fernie   BC       N  < 100,000          2  5901012
# 8         30   Grand Forks   BC       N  < 100,000          1  5905032
# 9         31     Greenwood   BC       N  < 100,000          2  5905042
# 10        34     Kimberley   BC       N  < 100,000          1  5901028
# 11        38        Nelson   BC       N  < 100,000          2  5903015
# ...

# %%
majCity.plot()
# Out:
# <AxesSubplot:>

# %%
finalGas
# Out:
# GEO       Calgary, Alberta  \
# REF_DATE
# 1990-01               47.9
# 1990-02               48.9
# 1990-03               49.7
# 1990-04               51.9
# 1990-05               51.9
# ...                    ...
# 2021-11              141.9
# 2021-12              139.5
# 2022-01              138.9
# 2022-02              145.4
# 2022-03              164.7
#
# GEO       Charlottetown and Summerside, Prince Edward Island  \
# REF_DATE
# 1990-01                                                54.6
# 1990-02                                                54.8
# 1990-03                                                55.0
# 1990-04                                                56.4
# 1990-05                                                56.8
# ...                                                     ...
# 2021-11                                               143.5
# 2021-12                                               134.6
# 2022-01                                               143.5
# ...

# %%
finalGas["Alberta"] = finalGas["Calgary, Alberta"] + finalGas["Edmonton, Alberta"]
finalGas
# Out:
# GEO       Calgary, Alberta  \
# REF_DATE
# 1990-01               47.9
# 1990-02               48.9
# 1990-03               49.7
# 1990-04               51.9
# 1990-05               51.9
# ...                    ...
# 2021-11              141.9
# 2021-12              139.5
# 2022-01              138.9
# 2022-02              145.4
# 2022-03              164.7
#
# GEO       Charlottetown and Summerside, Prince Edward Island  \
# REF_DATE
# 1990-01                                                54.6
# 1990-02                                                54.8
# 1990-03                                                55.0
# 1990-04                                                56.4
# 1990-05                                                56.8
# ...                                                     ...
# 2021-11                                               143.5
# 2021-12                                               134.6
# 2022-01                                               143.5
# ...

# %%
finalGas["Alberta"] = finalGas["Alberta"] / 2

# %%
finalGas
# Out:
# GEO       Charlottetown and Summerside, Prince Edward Island  \
# REF_DATE
# 1990-01                                                54.6
# 1990-02                                                54.8
# 1990-03                                                55.0
# 1990-04                                                56.4
# 1990-05                                                56.8
# ...                                                     ...
# 2021-11                                               143.5
# 2021-12                                               134.6
# 2022-01                                               143.5
# 2022-02                                               154.8
# 2022-03                                               172.4
#
# GEO       Halifax, Nova Scotia  Saint John, New Brunswick  \
# REF_DATE
# 1990-01                    NaN                        NaN
# 1990-02                    NaN                        NaN
# ...

# %%
finalGas["Quebec"] = finalGas["Montréal, Quebec"] + finalGas["Québec, Quebec"]
finalGas["Quebec"] = finalGas["Quebec"] / 2
finalGas
# Out:
# GEO       Calgary, Alberta  \
# REF_DATE
# 1990-01               47.9
# 1990-02               48.9
# 1990-03               49.7
# 1990-04               51.9
# 1990-05               51.9
# ...                    ...
# 2021-11              141.9
# 2021-12              139.5
# 2022-01              138.9
# 2022-02              145.4
# 2022-03              164.7
#
# GEO       Charlottetown and Summerside, Prince Edward Island  \
# REF_DATE
# 1990-01                                                54.6
# 1990-02                                                54.8
# 1990-03                                                55.0
# 1990-04                                                56.4
# 1990-05                                                56.8
# ...                                                     ...
# 2021-11                                               143.5
# 2021-12                                               134.6
# 2022-01                                               143.5
# ...

# %%
finalGas["Saskatchewan"] = finalGas["Regina, Saskatchewan"] + finalGas["Saskatoon, Saskatchewan"]
finalGas["Saskatchewan"] = finalGas["Saskatchewan"] / 2
finalGas
# Out:
# GEO       Calgary, Alberta  \
# REF_DATE
# 1990-01               47.9
# 1990-02               48.9
# 1990-03               49.7
# 1990-04               51.9
# 1990-05               51.9
# ...                    ...
# 2021-11              141.9
# 2021-12              139.5
# 2022-01              138.9
# 2022-02              145.4
# 2022-03              164.7
#
# GEO       Charlottetown and Summerside, Prince Edward Island  \
# REF_DATE
# 1990-01                                                54.6
# 1990-02                                                54.8
# 1990-03                                                55.0
# 1990-04                                                56.4
# 1990-05                                                56.8
# ...                                                     ...
# 2021-11                                               143.5
# 2021-12                                               134.6
# 2022-01                                               143.5
# ...

# %%
finalGas["British Columbia"] = finalGas["Vancouver, British Columbia"] + finalGas["Victoria, British Columbia"]
finalGas["British Columbia"] = finalGas["British Columbia"] / 2
finalGas
# Out:
# GEO       Calgary, Alberta  \
# REF_DATE
# 1990-01               47.9
# 1990-02               48.9
# 1990-03               49.7
# 1990-04               51.9
# 1990-05               51.9
# ...                    ...
# 2021-11              141.9
# 2021-12              139.5
# 2022-01              138.9
# 2022-02              145.4
# 2022-03              164.7
#
# GEO       Charlottetown and Summerside, Prince Edward Island  \
# REF_DATE
# 1990-01                                                54.6
# 1990-02                                                54.8
# 1990-03                                                55.0
# 1990-04                                                56.4
# 1990-05                                                56.8
# ...                                                     ...
# 2021-11                                               143.5
# 2021-12                                               134.6
# 2022-01                                               143.5
# ...

# %%
del finalGas["Calgary, Alberta"]

# %%
del finalGas["Edmonton, Alberta"]
del finalGas["Montréal, Quebec"]
del finalGas["Ottawa-Gatineau, Ontario part, Ontario/Quebec"]
del finalGas["Québec, Quebec"]
del finalGas["Regina, Saskatchewan"]
del finalGas["Vancouver, British Columbia"]
del finalGas["Victoria, British Columbia"]
del finalGas["Toronto, Ontario"]
finalGas
# Out:
# GEO       Charlottetown and Summerside, Prince Edward Island  \
# REF_DATE
# 1990-01                                                54.6
# 1990-02                                                54.8
# 1990-03                                                55.0
# 1990-04                                                56.4
# 1990-05                                                56.8
# ...                                                     ...
# 2021-11                                               143.5
# 2021-12                                               134.6
# 2022-01                                               143.5
# 2022-02                                               154.8
# 2022-03                                               172.4
#
# GEO       Halifax, Nova Scotia  Saint John, New Brunswick  \
# REF_DATE
# 1990-01                    NaN                        NaN
# 1990-02                    NaN                        NaN
# ...

# %%
del finalGas["Saskatoon, Saskatchewan"]
